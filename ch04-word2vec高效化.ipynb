# %% [markdown]
# # Negative Sampling Loss实现
#
# https://github.com/oreilly-japan/deep-learning-from-scratch-2/blob/master/ch04/negative_sampling_layer.py

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.np import *  # import numpy as np
from common.layers import Embedding, SigmoidWithLoss
import collections


class EmbeddingDot:
    def __init__(self, W):
        self.embed = Embedding(W)
        self.params = self.embed.params
        self.grads = self.embed.grads
        self.cache = None

    def forward(self, h, idx):
        target_W = self.embed.forward(idx)
        out = np.sum(target_W * h, axis=1)

        self.cache = (h, target_W)
        return out

    def backward(self, dout):
        h, target_W = self.cache
        dout = dout.reshape(dout.shape[0], 1)

        dtarget_W = dout * h
        self.embed.backward(dtarget_W)
        dh = dout * target_W
        return dh


class UnigramSampler:
    def __init__(self, corpus, power, sample_size):
        self.sample_size = sample_size
        self.vocab_size = None
        self.word_p = None

        counts = collections.Counter()
        for word_id in corpus:
            counts[word_id] += 1

        vocab_size = len(counts)
        self.vocab_size = vocab_size

        self.word_p = np.zeros(vocab_size)
        for i in range(vocab_size):
            self.word_p[i] = counts[i]

        self.word_p = np.power(self.word_p, power)
        self.word_p /= np.sum(self.word_p)

    def get_negative_sample(self, target):
        batch_size = target.shape[0]

        if not GPU:
            negative_sample = np.zeros((batch_size, self.sample_size), dtype=np.int32)

            for i in range(batch_size):
                p = self.word_p.copy()
                target_idx = target[i]
                p[target_idx] = 0
                p /= p.sum()
                negative_sample[i, :] = np.random.choice(self.vocab_size, size=self.sample_size, replace=False, p=p)
        else:
            # 使用GPU(cupy）计算时，速度优先
            # 目标中可能包含负样本
            negative_sample = np.random.choice(self.vocab_size, size=(batch_size, self.sample_size),
                                               replace=True, p=self.word_p)

        return negative_sample


class NegativeSamplingLoss:
    def __init__(self, W, corpus, power=0.75, sample_size=5):
        self.sample_size = sample_size
        self.sampler = UnigramSampler(corpus, power, sample_size)
        self.loss_layers = [SigmoidWithLoss() for _ in range(sample_size + 1)]
        self.embed_dot_layers = [EmbeddingDot(W) for _ in range(sample_size + 1)]

        self.params, self.grads = [], []
        for layer in self.embed_dot_layers:
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, h, target):
        batch_size = target.shape[0]
        negative_sample = self.sampler.get_negative_sample(target)

        # 正样本前向传播
        score = self.embed_dot_layers[0].forward(h, target)
        correct_label = np.ones(batch_size, dtype=np.int32)
        loss = self.loss_layers[0].forward(score, correct_label)

        # 负样本前向传播
        negative_label = np.zeros(batch_size, dtype=np.int32)
        for i in range(self.sample_size):
            negative_target = negative_sample[:, i]
            score = self.embed_dot_layers[1 + i].forward(h, negative_target)
            loss += self.loss_layers[1 + i].forward(score, negative_label)

        return loss

    def backward(self, dout=1):
        dh = 0
        for l0, l1 in zip(self.loss_layers, self.embed_dot_layers):
            dscore = l0.backward(dout)
            dh += l1.backward(dscore)

        return dh

# %% [markdown]
# # cbow实现
#
# https://github.com/oreilly-japan/deep-learning-from-scratch-2/blob/master/ch04/cbow.py

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.np import *  # import numpy as np
from common.layers import Embedding
#from ch04.negative_sampling_layer import NegativeSamplingLoss


class CBOW:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size

        # 权重初始化
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(V, H).astype('f')

        # 生成层
        self.in_layers = []
        for i in range(2 * window_size):
            layer = Embedding(W_in)  # 使用Embedding层
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)

        # 将所有的权重和梯度汇总到列表
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 设置单词的离散表示成员变量
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = 0
        for i, layer in enumerate(self.in_layers):
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        return loss

    def backward(self, dout=1):
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self.in_layers:
            layer.backward(dout)
        return None

# %% [markdown]
# # skip gram实现
#
# https://github.com/oreilly-japan/deep-learning-from-scratch-2/blob/master/ch04/skip_gram.py

# %%
# coding: utf-8
import sys
sys.path.append('..')  # 为导入父目录中的文件而进行的设置
from common.layers import *
#from ch04.negative_sampling_layer import NegativeSamplingLoss


class SkipGram:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size
        rn = np.random.randn

        # 权重初始化
        W_in = 0.01 * rn(V, H).astype('f')
        W_out = 0.01 * rn(V, H).astype('f')

        # 生成层
        self.in_layer = Embedding(W_in)
        self.loss_layers = []
        for i in range(2 * window_size):
            layer = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)
            self.loss_layers.append(layer)

        # 将所有的权重和梯度汇总到列表
        layers = [self.in_layer] + self.loss_layers
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 设置单词的离散表示成员变量
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = self.in_layer.forward(target)

        loss = 0
        for i, layer in enumerate(self.loss_layers):
            loss += layer.forward(h, contexts[:, i])
        return loss

    def backward(self, dout=1):
        dh = 0
        for i, layer in enumerate(self.loss_layers):
            dh += layer.backward(dout)
        self.in_layer.backward(dh)
        return None

# %% [markdown]
# # 训练
#
# https://github.com/oreilly-japan/deep-learning-from-scratch-2/blob/master/ch04/train.py

# %%
# coding: utf-8
import sys
sys.path.append('..')
import numpy as np
from common import config
# 如果使用GPU运行，要取消下面的注释（需要cupy）
# ===============================================
# config.GPU = True
# ===============================================
import pickle
from common.trainer import Trainer
from common.optimizer import Adam
#from cbow import CBOW
#from skip_gram import SkipGram
from common.util import create_contexts_target, to_cpu, to_gpu
from dataset import ptb


# 超参数设置
window_size = 5
hidden_size = 100
batch_size = 100
max_epoch = 10

# 读入数据
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)
if config.GPU:
    contexts, target = to_gpu(contexts), to_gpu(target)

# 生成模型等
model = CBOW(vocab_size, hidden_size, window_size, corpus)
# model = SkipGram(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 开始学习
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 为了之后也能使用，保存必要的数据
word_vecs = model.word_vecs
if config.GPU:
    word_vecs = to_cpu(word_vecs)
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'  # or 'skipgram_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# | epoch 1 |  iter 1 / 9295 | time 0[s] | loss 4.16
# | epoch 1 |  iter 21 / 9295 | time 1[s] | loss 4.16
# | epoch 1 |  iter 41 / 9295 | time 3[s] | loss 4.15
# | epoch 1 |  iter 61 / 9295 | time 4[s] | loss 4.13
# | epoch 1 |  iter 81 / 9295 | time 6[s] | loss 4.05
# | epoch 1 |  iter 101 / 9295 | time 7[s] | loss 3.93
# | epoch 1 |  iter 121 / 9295 | time 9[s] | loss 3.78
# | epoch 1 |  iter 141 / 9295 | time 10[s] | loss 3.62
# | epoch 1 |  iter 161 / 9295 | time 12[s] | loss 3.51
# | epoch 1 |  iter 181 / 9295 | time 13[s] | loss 3.37
# | epoch 1 |  iter 201 / 9295 | time 15[s] | loss 3.25
# | epoch 1 |  iter 221 / 9295 | time 17[s] | loss 3.16
# | epoch 1 |  iter 241 / 9295 | time 19[s] | loss 3.08
# | epoch 1 |  iter 261 / 9295 | time 21[s] | loss 3.04
# | epoch 1 |  iter 281 / 9295 | time 23[s] | loss 2.96
# | epoch 1 |  iter 301 / 9295 | time 24[s] | loss 2.92
# | epoch 1 |  iter 321 / 9295 | time 26[s] | loss 2.90
# | epoch 1 |  iter 341 / 9295 | time 28[s] | loss 2.83
# | epoch 1 |  iter 361 / 9295 | time 30[s] | loss 2.82
# | epoch 1 |  iter 381 / 9295 | time 32[s] | loss 2.78
# | epoch 1 |  iter 401 / 9295 | time 34[s] | loss 2.76
# | epoch 1 |  iter 421 / 9295 | time 36[s] | loss 2.74
# | epoch 1 |  iter 441 / 9295 | time 38[s] | loss 2.70
# | epoch 1 |  iter 461 / 9295 | time 40[s] | loss 2.71
# | epoch 1 |  iter 481 / 9295 | time 42[s] | loss 2.68
# | epoch 1 |  iter 501 / 9295 | time 44[s] | loss 2.70
# | epoch 1 |  iter 521 / 9295 | time 45[s] | loss 2.67
# | epoch 1 |  iter 541 / 9295 | time 48[s] | loss 2.64
# | epoch 1 |  iter 561 / 9295 | time 50[s] | loss 2.65
# | epoch 1 |  iter 581 / 9295 | time 52[s] | loss 2.67
# | epoch 1 |  iter 601 / 9295 | time 53[s] | loss 2.61
# | epoch 1 |  iter 621 / 9295 | time 55[s] | loss 2.63
# | epoch 1 |  iter 641 / 9295 | time 57[s] | loss 2.65
# | epoch 1 |  iter 661 / 9295 | time 59[s] | loss 2.60
# | epoch 1 |  iter 681 / 9295 | time 61[s] | loss 2.62
# | epoch 1 |  iter 701 / 9295 | time 63[s] | loss 2.59
# | epoch 1 |  iter 721 / 9295 | time 65[s] | loss 2.59
# | epoch 1 |  iter 741 / 9295 | time 67[s] | loss 2.60
# | epoch 1 |  iter 761 / 9295 | time 69[s] | loss 2.61
# | epoch 1 |  iter 781 / 9295 | time 71[s] | loss 2.60
# | epoch 1 |  iter 801 / 9295 | time 72[s] | loss 2.57
# | epoch 1 |  iter 821 / 9295 | time 74[s] | loss 2.61
# | epoch 1 |  iter 841 / 9295 | time 76[s] | loss 2.59
# | epoch 1 |  iter 861 / 9295 | time 78[s] | loss 2.57
# | epoch 1 |  iter 881 / 9295 | time 80[s] | loss 2.58
# | epoch 1 |  iter 901 / 9295 | time 82[s] | loss 2.57
# | epoch 1 |  iter 921 / 9295 | time 83[s] | loss 2.56
# | epoch 1 |  iter 941 / 9295 | time 85[s] | loss 2.54
# | epoch 1 |  iter 961 / 9295 | time 87[s] | loss 2.54
# | epoch 1 |  iter 981 / 9295 | time 89[s] | loss 2.55
# | epoch 1 |  iter 1001 / 9295 | time 91[s] | loss 2.53
# | epoch 1 |  iter 1021 / 9295 | time 92[s] | loss 2.55
# | epoch 1 |  iter 1041 / 9295 | time 95[s] | loss 2.55
# | epoch 1 |  iter 1061 / 9295 | time 97[s] | loss 2.53
# | epoch 1 |  iter 1081 / 9295 | time 99[s] | loss 2.53
# | epoch 1 |  iter 1101 / 9295 | time 101[s] | loss 2.54
# | epoch 1 |  iter 1121 / 9295 | time 103[s] | loss 2.55
# | epoch 1 |  iter 1141 / 9295 | time 105[s] | loss 2.54
# | epoch 1 |  iter 1161 / 9295 | time 106[s] | loss 2.50
# | epoch 1 |  iter 1181 / 9295 | time 108[s] | loss 2.52
# | epoch 1 |  iter 1201 / 9295 | time 110[s] | loss 2.53
# | epoch 1 |  iter 1221 / 9295 | time 112[s] | loss 2.52
# | epoch 1 |  iter 1241 / 9295 | time 114[s] | loss 2.54
# | epoch 1 |  iter 1261 / 9295 | time 116[s] | loss 2.55
# | epoch 1 |  iter 1281 / 9295 | time 118[s] | loss 2.55
# | epoch 1 |  iter 1301 / 9295 | time 120[s] | loss 2.54
# | epoch 1 |  iter 1321 / 9295 | time 122[s] | loss 2.54
# | epoch 1 |  iter 1341 / 9295 | time 123[s] | loss 2.53
# | epoch 1 |  iter 1361 / 9295 | time 125[s] | loss 2.50
# | epoch 1 |  iter 1381 / 9295 | time 127[s] | loss 2.52
# | epoch 1 |  iter 1401 / 9295 | time 129[s] | loss 2.49
# | epoch 1 |  iter 1421 / 9295 | time 131[s] | loss 2.56
# | epoch 1 |  iter 1441 / 9295 | time 132[s] | loss 2.49
# | epoch 1 |  iter 1461 / 9295 | time 134[s] | loss 2.51
# | epoch 1 |  iter 1481 / 9295 | time 136[s] | loss 2.50
# | epoch 1 |  iter 1501 / 9295 | time 138[s] | loss 2.52
# | epoch 1 |  iter 1521 / 9295 | time 140[s] | loss 2.53
# | epoch 1 |  iter 1541 / 9295 | time 141[s] | loss 2.49
# | epoch 1 |  iter 1561 / 9295 | time 143[s] | loss 2.53
# | epoch 1 |  iter 1581 / 9295 | time 145[s] | loss 2.54
# | epoch 1 |  iter 1601 / 9295 | time 147[s] | loss 2.52
# | epoch 1 |  iter 1621 / 9295 | time 149[s] | loss 2.50
# | epoch 1 |  iter 1641 / 9295 | time 151[s] | loss 2.50
# | epoch 1 |  iter 1661 / 9295 | time 152[s] | loss 2.47
# | epoch 1 |  iter 1681 / 9295 | time 154[s] | loss 2.52
# | epoch 1 |  iter 1701 / 9295 | time 156[s] | loss 2.48
# | epoch 1 |  iter 1721 / 9295 | time 158[s] | loss 2.50
# | epoch 1 |  iter 1741 / 9295 | time 160[s] | loss 2.49
# | epoch 1 |  iter 1761 / 9295 | time 162[s] | loss 2.50
# | epoch 1 |  iter 1781 / 9295 | time 163[s] | loss 2.47
# | epoch 1 |  iter 1801 / 9295 | time 165[s] | loss 2.52
# | epoch 1 |  iter 1821 / 9295 | time 167[s] | loss 2.50
# | epoch 1 |  iter 1841 / 9295 | time 169[s] | loss 2.49
# | epoch 1 |  iter 1861 / 9295 | time 171[s] | loss 2.47
# | epoch 1 |  iter 1881 / 9295 | time 173[s] | loss 2.51
# | epoch 1 |  iter 1901 / 9295 | time 175[s] | loss 2.51
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9e6cfe114534> in <module>
#      38
#      39 # 开始学习
# ---> 40 trainer.fit(contexts, target, max_epoch, batch_size)
#      41 trainer.plot()
#      42
#
# ~\deep-learning-from-scratch-2-nlp-notebook\common\trainer.py in fit(self, x, t, max_epoch, batch_size, max_grad, eval_interval)
#      38                 # 勾配を求め、パラメータを更新
#      39                 loss = model.forward(batch_x, batch_t)
# ---> 40                 model.backward()
#      41                 params, grads = remove_duplicate(model.params, model.grads)  # 共有された重みを1つに集約
#      42                 if max_grad is not None:
#
# <ipython-input-2-6d6311a932b3> in backward(self, dout)
#      44         dout *= 1 / len(self.in_layers)
#      45         for layer in self.in_layers:
# ---> 46             layer.backward(dout)
#      47         return None
#
# ~\deep-learning-from-scratch-2-nlp-notebook\common\layers.py in backward(self, dout)
#     164         dW, = self.grads
#     165         dW[...] = 0
# --> 166         np.add.at(dW, self.idx, dout)
#     167         return None
#
# KeyboardInterrupt:

# %% [markdown]
# # 评估模型
#
# https://github.com/oreilly-japan/deep-learning-from-scratch-2/blob/master/ch04/eval.py

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.util import most_similar, analogy
import pickle


pkl_file = 'cbow_params.pkl'
# pkl_file = 'skipgram_params.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']

# most similar task
querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)

# analogy task
print('-'*50)
analogy('king', 'man', 'queen',  word_to_id, id_to_word, word_vecs)
analogy('take', 'took', 'go',  word_to_id, id_to_word, word_vecs)
analogy('car', 'cars', 'child',  word_to_id, id_to_word, word_vecs)
analogy('good', 'better', 'bad', word_to_id, id_to_word, word_vecs)
# Out:
# [query] you
#  we: 0.6103515625
#  someone: 0.59130859375
#  i: 0.55419921875
#  something: 0.48974609375
#  anyone: 0.47314453125
#
# [query] year
#  month: 0.71875
#  week: 0.65234375
#  spring: 0.62744140625
#  summer: 0.6259765625
#  decade: 0.603515625
#
# [query] car
#  luxury: 0.497314453125
#  arabia: 0.47802734375
#  auto: 0.47119140625
#  disk-drive: 0.450927734375
#  travel: 0.4091796875
#
# [query] toyota
#  ford: 0.55078125
#  instrumentation: 0.509765625
#  mazda: 0.49365234375
#  bethlehem: 0.47509765625
#  nissan: 0.474853515625
# --------------------------------------------------
#
# [analogy] king:man = queen:?
#  woman: 5.16015625
#  veto: 4.9296875
#  ounce: 4.69140625
#  earthquake: 4.6328125
#  successor: 4.609375
#
# [analogy] take:took = go:?
#  went: 4.55078125
#  points: 4.25
#  began: 4.09375
#  comes: 3.98046875
#  oct.: 3.90625
#
# [analogy] car:cars = child:?
#  children: 5.21875
#  average: 4.7265625
#  yield: 4.20703125
#  cattle: 4.1875
#  priced: 4.1796875
#
# [analogy] good:better = bad:?
#  more: 6.6484375
#  less: 6.0625
#  rather: 5.21875
#  slower: 4.734375
#  greater: 4.671875
